# %%
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName('mylogreg').getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
my_data = spark.read.format('libsvm').load('sample_libsvm_data.txt')

# %%
my_data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[124,125,126...|
# |  1.0|(692,[152,153,154...|
# |  1.0|(692,[151,152,153...|
# |  0.0|(692,[129,130,131...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[99,100,101,...|
# |  0.0|(692,[154,155,156...|
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[154,155,156...|
# |  0.0|(692,[153,154,155...|
# |  0.0|(692,[151,152,153...|
# |  1.0|(692,[129,130,131...|
# |  0.0|(692,[154,155,156...|
# |  1.0|(692,[150,151,152...|
# |  0.0|(692,[124,125,126...|
# |  0.0|(692,[152,153,154...|
# |  1.0|(692,[97,98,99,12...|
# |  1.0|(692,[124,125,126...|
# +-----+--------------------+
# only showing top 20 rows

# %%
my_log_reg_model = LogisticRegression()

# %%
fitted_logreg_model = my_log_reg_model.fit(my_data)

# %%
log_summary = fitted_logreg_model.summary

# %%
log_summary.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[127,128,129...|[20.3777627514872...|[0.99999999858729...|       0.0|
# |  1.0|(692,[158,159,160...|[-21.114014198868...|[6.76550380000472...|       1.0|
# |  1.0|(692,[124,125,126...|[-23.743613234676...|[4.87842678716177...|       1.0|
# |  1.0|(692,[152,153,154...|[-19.192574012720...|[4.62137287298144...|       1.0|
# |  1.0|(692,[151,152,153...|[-20.125398874699...|[1.81823629113068...|       1.0|
# |  0.0|(692,[129,130,131...|[20.4890549504196...|[0.99999999873608...|       0.0|
# |  1.0|(692,[158,159,160...|[-21.082940212814...|[6.97903542823766...|       1.0|
# |  1.0|(692,[99,100,101,...|[-19.622713503550...|[3.00582577446132...|       1.0|
# |  0.0|(692,[154,155,156...|[21.1594863606582...|[0.99999999935352...|       0.0|
# |  0.0|(692,[127,128,129...|[28.1036706837287...|[0.99999999999937...|       0.0|
# |  1.0|(692,[154,155,156...|[-21.054076780106...|[7.18340962960324...|       1.0|
# |  0.0|(692,[153,154,155...|[26.9648490510184...|[0.99999999999805...|       0.0|
# |  0.0|(692,[151,152,153...|[32.7855654161400...|[0.99999999999999...|       0.0|
# |  1.0|(692,[129,130,131...|[-20.331839179667...|[1.47908944089721...|       1.0|
# |  0.0|(692,[154,155,156...|[21.7830579106564...|[0.99999999965347...|       0.0|
# |  1.0|(692,[150,151,152...|[-20.640562103728...|[1.08621994880353...|       1.0|
# |  0.0|(692,[124,125,126...|[22.6400775503731...|[0.99999999985292...|       0.0|
# |  0.0|(692,[152,153,154...|[38.0712919910909...|           [1.0,0.0]|       0.0|
# |  1.0|(692,[97,98,99,12...|[-19.830803265627...|[2.44113371545874...|       1.0|
# |  1.0|(692,[124,125,126...|[-21.016054806036...|[7.46179590484091...|       1.0|
# +-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
lr_train, lr_test = my_data.randomSplit([0.7,0.3])

# %%
final_model = LogisticRegression()

# %%
fit_final = final_model.fit(lr_train)

# %%
prediction_and_labels = fit_final.evaluate(lr_test)

# %%
prediction_and_labels.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[100,101,102...|[2.89265045951720...|[0.94748192476706...|       0.0|
# |  0.0|(692,[123,124,125...|[32.6262696881793...|[0.99999999999999...|       0.0|
# |  0.0|(692,[123,124,125...|[35.4793683668734...|[0.99999999999999...|       0.0|
# |  0.0|(692,[126,127,128...|[29.6080291796075...|[0.99999999999986...|       0.0|
# |  0.0|(692,[126,127,128...|[36.0560753596509...|[0.99999999999999...|       0.0|
# |  0.0|(692,[126,127,128...|[17.8881734063933...|[0.99999998296802...|       0.0|
# |  0.0|(692,[126,127,128...|[23.4401703644294...|[0.99999999993392...|       0.0|
# |  0.0|(692,[127,128,129...|[19.9993607985523...|[0.99999999793752...|       0.0|
# |  0.0|(692,[127,128,129...|[22.4298016480786...|[0.99999999981850...|       0.0|
# |  0.0|(692,[150,151,152...|[19.4263890392844...|[0.99999999634214...|       0.0|
# |  0.0|(692,[153,154,155...|[31.3841916137482...|[0.99999999999997...|       0.0|
# |  0.0|(692,[154,155,156...|[18.9513229237663...|[0.99999999411772...|       0.0|
# |  0.0|(692,[181,182,183...|[20.2927211878740...|[0.99999999846190...|       0.0|
# |  1.0|(692,[100,101,102...|[-27.176487721567...|[1.57543810319890...|       1.0|
# |  1.0|(692,[123,124,125...|[-24.035400117287...|[3.64383211098854...|       1.0|
# |  1.0|(692,[123,124,125...|[-23.490315232363...|[6.28471685748463...|       1.0|
# |  1.0|(692,[124,125,126...|[-25.297298300363...|[1.03162757249388...|       1.0|
# |  1.0|(692,[124,125,126...|[-25.402212966399...|[9.28878863227082...|       1.0|
# |  1.0|(692,[126,127,128...|[-23.835271562685...|[4.45115877076305...|       1.0|
# |  1.0|(692,[126,127,128...|[-23.099545880139...|[9.28955028084063...|       1.0|
# +-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

# %%
my_eval = BinaryClassificationEvaluator()

# %%
my_final_roc = my_eval.evaluate(prediction_and_labels.predictions)

# %%
my_final_roc
# Out:
# 1.0
